# %%
import pandas as pd

# %%
dataset={ 'cars':["BMW","FORD","MARUTI"],
         'color_code':[1,3,5]
        }
df=pd.DataFrame(dataset)
print(df)
# Out:
#      cars  color_code
# 0     BMW           1
# 1    FORD           3
# 2  MARUTI           5

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
a=[1,7,2]
df1=pd.Series(a)
print(df1)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
b=[1,3,4]
mydf=pd.Series(b,index=["x","y","z"])
print(mydf)
# Out:
# x    1
# y    3
# z    4
# dtype: int64

# %%
print(mydf['y'])
# Out:
# 3

# %%
import pandas as pd
dict1={'A':1,'B':2,'C':3}
v1=pd.Series(dict1)
print(v1)
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
import pandas as pd 
df3=pd.read_csv("/content/drive/Mydrive/colab notebooks/Datasets/Mall_customer.csv")
df3

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(df3.head())

# %%
print(df3.tail())

# %%
df3.head()

# %%
df.tail()

# %%
print(df3.info())

# %%
import pandas as pd 
pd.read_csv("healthcare_dataset.csv.zip")
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df4=pd.read_csv("healthcare_dataset.csv.zip")

# %%
df4.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
print(df4.head())
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
print(df4.tail())
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
#advance pandas

# %%
import pandas as pd
df5=pd.read_csv('Salary_Data.csv')
df5
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
print(df5)
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df5.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df5['Salary'].value_counts()
# Out:
# Salary
# 39343     1
# 46205     1
# 122391    1
# 112635    1
# 116969    1
# 105582    1
# 109431    1
# 113812    1
# 101302    1
# 98273     1
# 91738     1
# 93940     1
# 81363     1
# 83088     1
# 66029     1
# 67938     1
# 61111     1
# 57081     1
# 56957     1
# 55794     1
# 63218     1
# 57189     1
# 64445     1
# 54445     1
# 60150     1
# 56642     1
# 39891     1
# 43525     1
# 37731     1
# 121872    1
# Name: count, dtype: int64

# %%
df5['YearsExperience'].value_counts()
# Out:
# YearsExperience
# 3.2     2
# 4.0     2
# 1.1     1
# 5.3     1
# 10.3    1
# 9.6     1
# 9.5     1
# 9.0     1
# 8.7     1
# 8.2     1
# 7.9     1
# 7.1     1
# 6.8     1
# 6.0     1
# 5.9     1
# 5.1     1
# 1.3     1
# 4.9     1
# 4.5     1
# 4.1     1
# 3.9     1
# 3.7     1
# 3.0     1
# 2.9     1
# 2.2     1
# 2.0     1
# 1.5     1
# 10.5    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df5['Salary'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Salary'>

# %%
df5['YearsExperience'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='YearsExperience'>

# %%
(df5['YearsExperience'].value_counts()).sort_values()
# Out:
# YearsExperience
# 6.0     1
# 2.0     1
# 2.2     1
# 2.9     1
# 3.0     1
# 3.7     1
# 3.9     1
# 4.1     1
# 4.5     1
# 4.9     1
# 1.3     1
# 5.1     1
# 5.9     1
# 10.5    1
# 6.8     1
# 7.1     1
# 7.9     1
# 8.2     1
# 8.7     1
# 9.0     1
# 9.5     1
# 9.6     1
# 10.3    1
# 5.3     1
# 1.1     1
# 1.5     1
# 4.0     2
# 3.2     2
# Name: count, dtype: int64

# %%
(df5['Salary'].value_counts()).sort_values()
# Out:
# Salary
# 39343     1
# 43525     1
# 39891     1
# 56642     1
# 60150     1
# 54445     1
# 64445     1
# 57189     1
# 63218     1
# 55794     1
# 56957     1
# 57081     1
# 61111     1
# 67938     1
# 66029     1
# 83088     1
# 81363     1
# 93940     1
# 91738     1
# 98273     1
# 101302    1
# 113812    1
# 109431    1
# 105582    1
# 116969    1
# 112635    1
# 122391    1
# 46205     1
# 37731     1
# 121872    1
# Name: count, dtype: int64

# %%
(df5['Salary'].value_counts()).sort_values(ascending=False)
# Out:
# Salary
# 39343     1
# 46205     1
# 37731     1
# 43525     1
# 39891     1
# 56642     1
# 60150     1
# 54445     1
# 64445     1
# 57189     1
# 63218     1
# 55794     1
# 56957     1
# 57081     1
# 61111     1
# 67938     1
# 66029     1
# 83088     1
# 81363     1
# 93940     1
# 91738     1
# 98273     1
# 101302    1
# 113812    1
# 109431    1
# 105582    1
# 116969    1
# 112635    1
# 122391    1
# 121872    1
# Name: count, dtype: int64

# %%
df5.sort_values('Salary')
# Out:
#     YearsExperience  Salary
# 2               1.5   37731
# 0               1.1   39343
# 4               2.2   39891
# 3               2.0   43525
# 1               1.3   46205
# 7               3.2   54445
# 11              4.0   55794
# 5               2.9   56642
# 12              4.0   56957
# 13              4.1   57081
# 9               3.7   57189
# 6               3.0   60150
# 14              4.5   61111
# 10              3.9   63218
# 8               3.2   64445
# 16              5.1   66029
# 15              4.9   67938
# 18              5.9   81363
# 17              5.3   83088
# 20              6.8   91738
# 19              6.0   93940
# 21              7.1   98273
# 22              7.9  101302
# 25              9.0  105582
# 24              8.7  109431
# 27              9.6  112635
# 23              8.2  113812
# 26              9.5  116969
# 29             10.5  121872
# 28             10.3  122391

# %%
df5.sort_values(['Salary','YearsExperience'])
# Out:
#     YearsExperience  Salary
# 2               1.5   37731
# 0               1.1   39343
# 4               2.2   39891
# 3               2.0   43525
# 1               1.3   46205
# 7               3.2   54445
# 11              4.0   55794
# 5               2.9   56642
# 12              4.0   56957
# 13              4.1   57081
# 9               3.7   57189
# 6               3.0   60150
# 14              4.5   61111
# 10              3.9   63218
# 8               3.2   64445
# 16              5.1   66029
# 15              4.9   67938
# 18              5.9   81363
# 17              5.3   83088
# 20              6.8   91738
# 19              6.0   93940
# 21              7.1   98273
# 22              7.9  101302
# 25              9.0  105582
# 24              8.7  109431
# 27              9.6  112635
# 23              8.2  113812
# 26              9.5  116969
# 29             10.5  121872
# 28             10.3  122391

# %%
df5.shape
# Out:
# (30, 2)

# %%
df5.drop_duplicates(subset=['YearsExperience'])
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df5.drop_duplicate(subset=['YearsExperience','Salary']).shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4368\726641186.py in ?()
# ----> 1 df5.drop_duplicate(subset=['YearsExperience','Salary']).shape
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_duplicate'

# %%
df5.shape
# Out:
# (30, 2)

# %%
salary=df5.groupby('Salary')
salary

# %%
len(df5)
# Out:
# 30

# %%
len('Salary')
# Out:
# 6

# %%
Salary.size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 Salary.size()
#
# NameError: name 'Salary' is not defined

# %%
Salary.first()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Salary.first()
#
# NameError: name 'Salary' is not defined

# %%
#renaming & combining

# %%
import pandas as pd
import numpy as np
df1=pd .read_csv('')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df1=pd .read_csv('')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
df1.head()

# %%
#rename(),which ;let change column names.
df1.rename(columns={'Duration':'Timing'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #rename(),which ;let change column names.
# ----> 2 df1.rename(columns={'Duration':'Timing'})
#
# NameError: name 'df1' is not defined

# %%
#rename() lets you rename index values by specifying a index
df1.rename(index={0:'firstEntry',1:'secondEntry'})

# %%
df2=pd.read_csv('')

# %%
df2.head()

# %%
pd.concat([df1,df2])

# %%
#join() lets you combine different dataFRAME object which have an index in common.
df1.join(df2)

# %%
import pandas as pd
df3=pd.read_csv('')

# %%
df.head()
